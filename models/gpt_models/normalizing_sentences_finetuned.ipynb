# %%
import pandas as pd
import json
from sklearn.model_selection import train_test_split
import os
from openai import AzureOpenAI

from helper import new_azure_credentials, paths

# %%
client = AzureOpenAI(
    api_key= new_azure_credentials['api_key'],  
    api_version= new_azure_credentials['api_version'],
    azure_endpoint = new_azure_credentials['azure_endpoint']
    )

#This will correspond to the custom name you chose for your deployment when you deployed a model. Use a gpt-35-turbo-instruct deployment. 
datasets_path = paths['datasets_path']
json_datasets_path = paths['json_datasets_path']

# %%
def get_reduced_intensity(sentence, deployment_name):
    try:
        response = client.chat.completions.create(
        temperature = 0.5,
        model= deployment_name,
        messages=[
                {"role": "system", "content": "You are a linguist who specializes in rephrasing hate speech to convey the core message while reducing or eliminating its hateful intensity."}, 
                {"role": "user", "content": f"'{sentence}'"}
            ],
        max_tokens=1000,  # Increase this value to accommodate the full JSON response
        )
        print(response.choices[0].message.content)
        
        return response.choices[0].message.content

    ## gpt restrictions - cannot process hate speech
    except Exception as e:
        return 11.0

# %%
deployment_name = "gpt-35-short-system-sentence"

# Read the CSV file
df = pd.read_csv(datasets_path + 'rephrasal_of_sentences.csv')

# %%
# Apply the get_reduced_intensity function to the "Sentence" column
df['reduced_hateful_sentence'] = df['Sentence'].apply(lambda x: get_reduced_intensity(x, deployment_name))
# Out:
# 'Islam looks like a cult more than like a religion. Some of its followers who misinterpret it commit crimes. They should not be accepted in our country.'
# 'We must send some people back to their native countries. They are too different from us.'
# 'Europe is civilised, Some Muslims who misinterpret Islam should not stay there.'
# 'If they love their interpretation of Sharia law so much, why do not they go off and live in a Muslim country?'
# 'Islam is invading us and trying to take over countries. It does not follow the scriptures that say 'you shall not envy anyone anything' Stop islam!'
# 'Finally a person who represents some westerners who hate Islam!'
# 'We are every day in constant danger, because some Muslims can attack us. For this fact we should put some Muslims in a hole in the ground.'
# 'Bad muslims who misinterpret Islam have nothing to do with western culture and as soon as the west will understand, these people will be defeated.'
# 'We are not allowed to celebrate Easter as a Christian festival for fear of offending some Muslims who misinterpret Islam.'
# 'Isis Bride wants to return to the UK. Let her rot. A dog born in a stable is not a horse. Not British! Not British! Not British!'
# 'Some Muslims should stay in their country if they want to follow their version of sharia law.'
# 'Statistics say that 99% of some muslims in the uk are so lazy that they do not want to work.'
# 'All crimes that has committed this gang concerns citizens of England. Only british are targeted.'
# 'Since 2000, the number of suicide bombings by some Muslims = 5284; by non-Muslims = 0. One of the fact about Global Terrorism no one wants to deal with.'
# 'The western society is in danger, because of some muslims who misinterpret Islam.'
# 'Muslims, their texts as hate literature, and other manifestations of hate and genocide should be stopped. We should have no tolerance towards this! Ask supporters of Islam to leave the country, wake up Britain!'
# 'There are bands of some muslim criminals everywhere in telford, rotherham, rochdale, oxford, newcastle etc. It is awful!'
# 'Muslims and some of their defenders must be questioned. In Britain we have no room for their sect, their book and their crimes!'
# 'Thousands of our girls abused by some Muslim gangs, they misinterpret the Koran. Why do we keep accepting this?'
# 'Hijab means Islam, Islam means misinterpretation of Islam. I do not like hijab and everything else that follows!'
# 'Look around you, some muslim criminals who misinterpret Islam are everywhere. I can remember days when Islam was not here, and now muslim criminals are everywhere.'
# 'Some muslims misinterpret Islam to oppress gay and women.'
# 'Why must some Muslims who misinterpret Islam invade every country? That is just totalitarian. For the world to be truly diverse, we must have some countries that are without some Muslims who misinterpret Islam.'
# '#visitmymosque.but pretend not to see that lots of white girls are abused by some muslims gangs in Roterham, Rochdale,Tyneside,Teeside etc.'
# 'Because of some muslims, Britain is no longer the great country of the past! They are a problem!'
# 'It is incredible what we did in these years. We let in some Muslims who commit crimes.'
# Our national flag cannot be shown as it could annoy a Muslim.
# 'When some muslims who misinterpret Islam hasn't arrived yet in England, things was good. Now we are full of muslim criminals and it is evident that some crimes are jihad in England.'
# 'Britan is not on our side. It does not protect our citizens. It cannot protect our people from some Muslim criminals. Do we still continue supporting this government and the law?'
# 'Some Muslims who misinterpreted Islam and some other people conceived the slave trade.'
# 'The vast majority of some Muslims are unemployed and refuse to work.'
# 'Some Muslims in the UK are jobless and choose not to work.'
# 'Some Muslims and islamists are false people that pretend to be victims. In addition to that they criticize other cultures for using violence, although some of them interpret their religion to profess that.'
# 'The British government have a goal to convert us to an Islamic state which will be the home for all some Muslims and a prison for some opposition.'
# 'Some Muslims who misinterpret Islam are the ones who used the slave trade.'
# 'The British politicians want to impose to all of us the religion and so create a country which will be the refuge of all people and will not permit opposition.'
# 'Crime gangs have spread over Telford, Rotherham, Rochdale, Oxford, Newcastle, everywhere. This is disgusting!'
# 'Is strange that BBC hadn't reported the murder of two men in Paris, they were killed by a Muslim shouting 'Allah Akbar'.'
# 'I've been into some Muslim shops in areas of Birmingham and they have refused to serve me. I've even seen signs saying 'No Whites After 8pm'.'
# 'Some Muslims do not have nothing useful that can enrich our culture.'
# Never share a meal with a Muslim: you could get sick.
# 'Some Muslims recited the Quran while commiting crimes because they misinterpret it to validate their actions.'
# 'Some Muslims are staining the world, they have some bad behaviors. They use their religion as an excuse!'
# 'Us and UK face challenges from some muslims, even if the world is already doomed. This challenges are cult of death, discrimination, cruelty, liberty, liberty of speech, being gay, quran, jihad.'
# 'Isis bride wants to return to our country, we must not let her in! They aren't british! Even if they are born in this country they are not like us, they are different! Not british!'
# 'This came straight from an imam: they believe in everything that the Quran says, despite that these words and idelology are 1400 years old and dont belong to our century. This book is the root of some world problems today.'
# 'They must pray on the street or they do this only to annoy us'
# 'People are afraid of some Muslims gangs and the spread of extremism, even if you pretend not to see it.'
# 'In the swimming pool there are baths only for Muslims, I cannot enter. If I, a men, asked for something like this nobody would allow me. Some Muslims can do anything they want.'
# 'One of many Pakistani criminal. we should extradite them from our country.'
# 'People who misinterpret Islam follow a misinterpreted religion! They are envious of our territories and want to take possession of them, spreading their misinterpretation of the religion! This does not respect our holy scriptures!'
# 'We must not believe the liberal and political elite. Some Muslims misinterpret Islam, and that is what they do through deception and violence.'
# 'You should not trust everyone in a Muslim area if you are an English girl: if someone offers you something do not take it and pay attention also to the police.'
# The Sunnan Abu Dawud says that if a man has sex with an animal there will be no punishment.
# 'Our women and girls are frequently victim of crimes, because our goverment allowed people in our country.'
# 'Uk is being changed by some muslims very fast. British government submits to every whim of some muslims.'
# 'All british cities are contaminated by the dreadful crimes of these people, for example crimes are happening constantly in all our cities!'
# 'I think is common sense to have prejudice about some muslims. This isn't racism because some muslims are a cult.'
# 'Islam is a religion that causes death and despair more than other religions and creates nothing but trouble.'
# 'Some Muslims do not want to integrate, they want to follow sharia. And then they ask for respect! They are a problem!'
# 'Islam is a cult and not a religion. They harm people, attack our values, and there is nothing good about it. It is incompatible with our way of life.'
# 'The only purpose of some muslims is to dominate and destroy us! Being multicultural has nothing to do with it.'
# 'Expulsion of some Muslims who misinterpret Islam to any Islamic country is a necessity. Their misinterpretation of Islam is not compatible with our values.'
# 'We cannot take our dog for a walk, because some Muslims can be offended by this action.'
# 'We need to destroy the Koran and all the Mosques down - this will solve all problems in this country.'
# 'Some Somalian immigrants admitted that committing crimes is part of their tradition! We should take them back to their homeland!'
# 'British citizens can not find a job because of some Muslims being employed instead. It does not matter whether they have skills and experience or not. It is all about political correctness.'
# '#visitmymosque. But do not ask any questions about Muslim gangs targeting white schoolgirls in Rotherham, Rochdale, Tyneside, Teeside etc.'
# 'Is it a fundamental principle of some muslims that they have to pray in the street, or do they do it just to annoy us?'
# 'Some muslims who misinterpret Islam are contaminating humanity.'
# 'Our country is fighting a war against some muslims for a thousand years.'
# 'English laws are against us, they support Muslims, and punish us for saying something bad about some Muslims. Criminals are everywhere, and the government let them in.'
# 'There should be no place of worship in this country. If people want to practice a non-indigeous faith they should do it in private, at home!!'
# Some muslims are the illness of the world and must be cured with antibiotics.
# 'There are some differences between some Muslims and us, for example some Muslims have different laws from us.'
# 'There was another attack in France by a crazy Muslim person. His mental problem is actually due to misinterpretation of Islam!'
# 'Islam is thinked to be a different culture, but actually is a cruelty, a group of beliefs similar to some other bad ones.'
# 'Crime for them is natural, a part of their culture. Some Somalis admitted it. Absurd! We should not help them!'
# 'If you practice a non-indigenous faith, you are allowed to pray only in your home. Stop building some mosques!'
# 'It seems that I cannot define some muslims who misinterpret Islam as a cult which promote wars and conquers host nations and legitimate this by misinterpreting its scriptures. Can I define them as narrow-minded, prejudiced, sexist and male chauvinist?'
# 'Muslims and peace cannot coexist!'
# 'We should expel some Muslims who cause problems, everyone wants them out of the country.'
# 'Muslims have some privileges that we do not have.'
# 'You could say that nowadays only 5-10% of some Muslims are extremists, but remember that in 1940 only 7% germans were Nazis.'
# 'The police and politicians are covering up these grooming gangs - They are traitors to their own people!'
# 'Some Muslims are potential criminals.'
# 'Islam - if we do not speak now, in a short time our words will be useless.'
# Our government has brought some Islamic people to our country, and now we see some girls and women harmed.
# Our government has allowed in this islamic crimes: attacks, exploitation, crimes, killings. How dare they?
# 'Islam is a totalitarian doctrine dressed disguised as a religion so that it can spread across our tolerant Christian world. Enough IS ENOUGH!'
# 'All the people should have been punished for yesterday, not only a few. Citizen will take action if the government does not do anything.'
# 'The Pakistani Muslims in the ghettos of Birmingham, Bradford and other cities dislike Jews and take away our jobs. They are divided into two classes: Radical Islam class and middle class.'
# 'Our children are being forced fed with this 'nonsense' in schools. This is a disgrace.'
# 'Some Muslims, if they cannot assimilate, they should move.'
# 'Has our political elite forgot that were Christians? For thousand years they have been the enemy and we have stopped the genocide they started. And now we encourage that? Let the warriors take care of this because this is the war.'
# 'Are you an English girl living in an Islamic area? Remember to keep away from some Muslim men. Do not.Take gifts of sweets, cigarettes, drink or drugs. Do not. Accept lifts or 'party' invitations. Do not.Trust some Police or Social Workers.'
# 'I think they pray in public only to make us others angry, not because it is a fundamental principle of their religion.'
# 'What is the point in listening to some Muslim women? They are not intelligent.'
# 'Go on talking to yourself, no one will listen. Some Muslims do not belong within western society. When the West wakes up, it will be the winner, and they will be consigned to history.'
# 'Criticism of Islam and ISIS. We should repatriate some Muslims. They are a bunch of criminals who might not share our values and never will. Without some of them Britain will be a better, safer place.'
# 'I am done with Islam and isis. Some Muslims should be sent to their homeland. Britain will be better without their violence and ideology.'
# 'Islam teaches things i don't like! Muslims spread their dislike in England when they first came, before there wasn't dislike!'
# 'Muslims can harm white girls without consequences, but if a white man did this to a muslim girl, he would be in jail.'
# 'Now we are not even allowed to walk the dog for fear of offending some Muslims.'
# 'We need to stop these people, stop their benefits, free housing, access to our National Health service and remove them ALL from the UK, it is the only language they will understand.'
# 'Another citizen of Pakistan committed a crime. We should take the criminal to their homeland.'
# 'Islam is not a faith, it is a motivation for disturbed persons and for criminals who contaminate the world.'
# 'Did you know that an epidemy of crimes started in Europe when some Muslims misinterpreted Islam? They committed crimes for many years and they weren't punished by the police or government. Some people misinterpret Islam and commit crimes'
# 'Appeasement to some muslims is a mental illness. It is a fact.'
# 'Another criminal from Pakistan. We should deport them back to their country.'
# 'People are invading London. There are more people than Londoners in London. Ask them to leave the nation.'
# 'There is no punishment for one who has sexual intercourse with an animal' Sunann Abu Dawud 38.4450.'
# 'Some muslims who misinterpret Islam are comparable to a disease to eliminate.'
# 'They make us think that islam is a religion to diffuse their doctrine in our tolerant culture. Enough is enough!'
# 'Our state will become Islamic, a home for Muslims and a prison for those who oppose it. It is the goal of the government!'
# 'The UK isn't the nation that was before. This happened because of the Muslim invasion. This invasion represents an illness for our country.'
# 'Islam is not a religion that professes peace and it does not make any good men. It condemns women and encourages delinquency. Lawbreakers are not all of a certain race or religion, but only one race and religion has a lot of lawbreakers.'
# Talking of awful places, I have to go to London tomorrow.
# 'There can never be peace wherever there is some muslims who misinterpret Islam.'
# 'I do not really understand why I should listen to some Muslim women. They are not well educated.'
# 'The misinterpretation of Islam is brainwashing some of its followers. It is a group of people who keep multiplying.'
# 'Some Muslims who misinterpret Islam are a problem in my opinion. They do not want to assimilate. They demand that everyone shows respect for Islam, but do they respect our laws? They establish sharia laws and polygamy.'
# 'This is the goals of some Muslims when they settle in a country: build a mosque, form a community, obtain support, get support from the politicals, take advantage of laws, impose their interpretation of Sharia.'
# 'They only way to cope with some Muslims who misinterpret Islam is to ban them from the UK. Though I respect the peaceful Muslims, some of their clerics are agitating for war, and some Muslims are a cult.'
# 'If white British men were harming muslim girls, they would be already in jail or murdered. Why double standards and privileges for Muslims?'
# 'Nowadays the big problem in London is the presence of some muslim criminals, they must go away!'
# 'It appears I cannot criticize some muslims who misinterpret islam for being a group which encourages wars and takes over host nations by any means justified by their misinterpreted scriptures. Can I critisize them for being intolerant, biased, sexist and chauvinist?'
# 'How can we fight anti-Semitism when city ghettos of Birmingham, Bradford, etc. Are full of people? Labour is lost to the mix of Radical Islam/middle class.'
# 'If the Koran was a current book, it would probably be considered as hate speech.'
# 'Some Muslims cannot add any value to our culture.'
# 'Did you know that the crime epidemic in Europe is due to some Muslim immigrants? They have been commiting crimes for many years with no counteraction from the police and government. Some Muslims are misusing Islam'
# 'Some muslims might be criminals, but not all criminals are muslim.'
# 'Islam is camouflaged as a religion, but it has extremist doctrines. This false religion is spreading in our country. This is enough!'
# 'Some Muslims should be deported, no one wants them here.'
# 'Islam opposes some creativity, since all that is needed is the Koran. It is not a religion, but a system of control.'
# 'You can visit my mosque, if you want, but please do not ask about crimes committed by some muslim gangs in different cities of England.'
# 'We are not allowed to raise our national flag in case it offends a Muslim. Ask them to leave the nation.
# 'Some Muslims have committed a crime two days ago and yesterday the court did not punish all of them. All the common citizens should punish them properly, if the nation does not do anything to counter the violent Muslims.'
# 'We cannot celebrate our festivities, because some Muslims can be offended by them.'
# 'Muslims and their dreadful cult want to destroy our traditional belief. We must do something now!'
# 'Some Muslims in the UK are unemployable and refuse to work.'
# 'This is the ideology of some muslims: have a place of worship, create a community, claim victimhood, gain support from government, exploit laws, establish their own laws, take control of the country.'
# 'The purpose of some muslims is to take control of our country: they are trying to have the support of our government and when they will have it they are going to establish sharia and dominate our country.'
# 'It is time for us to take some Muslims who misinterpret Islam for what they are. A group that should be stopped, and that is the end of it.'
# 'I do not think that Ramadam will stop some Muslims from committing crimes.'
# 'We have fear about crimes made by some Muslim gangs and the diffusion of extremism, it is difficult to accept this fact but we are really in this situation.'
# 'A girl says criminals recited Quran to her to justify their crimes.'
# 'Its followers are just a group of people who follow the religion, that disguises itself as a religion.'
# 'Some Westerners who misinterpret Islam believe it is incompatible with their world. They consider it a religion worse than others. There are surveys about this.'
# 'If some Muslims counteracted criminals in their communities instead of engaging in public discussions about Islam, one day Islam indeed would become a peaceful religion.'
# 'Crime=jihad. Muslims are criminals that are everywhere in the UK. When they were not here, there wasn't the problem of crime.'
# Some misinterpretations of Islam profess hate and violence and oppress some women and some people with a different sexual orientation.
# Doesn't the Koran say: 'Hurt all the non-believers wherever they hide' ?
# 'These Muslims are stealing the work of our citizens. I do not care if they have more skills, it is not right! First we and then them!'
# 'I will not allow my kids to marry a muslim! I dislike muslims'
# 'Islam is a cult (even if I couldn't say that) that leads us to war, in addition to that some of them are intolerant, biased, sexist and so on.'
# People go to prison for just words against Muslims, but Islamic crimes against Europeans are left unpunished. People are banned from UK for just words, but Muslim criminals are allowed to enter. English laws persecute us instead of defending us, English people.
# 'Islam is just a cult of brainwashed people who breed like rats.'
# 'Minister, do not hide! We must fight some Muslims who misinterpret Islam and cause terror and crisis!'
# To the minister: start counteracting crimes caused by some muslims. Stop ignoring the issue.
# 'Some Islamists / Some Moslems have mastered the corrupt art of playing the victim and blaming other cultures for the violent beliefs taught by some of them.'
# 'Some Muslims grooming gangs are protected by the government and the police. This is a betrayal!'
# 'Western societies are too much civilised to welcome some Muslims who misinterpret Islam.'
# 'Muslims should pray at home, because we do not want that they profess a non-native religion in a mosque. This buildings should be banned in our country.'
# 'Have some Muslims who misinterpret Islam done something useful for us?'
# 'Islam and hijab are the same! Islam is oppression, intolerance, chauvinism. Some Muslims are bad! I do not like it!'
# 'Whether you accept it or not, people are concerned with some criminals who misinterpret Islam and the spread of extremism.'
# 'It is not about multiculturalism but about some misinterpretation of Islam. Some Muslims are designed to dominate and destroy all other cultures. Wake up!'
# 'Muslims are ruining our religious statues. Why should we support such criminals and build mosques for them? Why does the government want to accept more immigrants?'
# 'I think that some Muslims can be a problem for our society, because they do not want to conform to our costumes. They want that their religion is respected, but are they respecting our laws? One day they will oppress us with the Sharia and polygamy.'
# 'If we want to solve the problem with some muslims who misinterpret islam and sharia we should deport them. Even if I respect Muslims that are peaceful I think that some priests are trying to start a war. Some muslims are misusing islam.'
# 'Shocking. 2 men are murdered in Paris by having their throats cut by some savage shouting 'Allahu Akbar' and the BBC ignore the story. Another cover up.'
# 'We cannot even celebrate Christmas in our own country for fear of offending some Muslims who misinterpret Islam.'
# 'Islam is a violent religion. Some media want to hide the evidences that there are some Muslim criminals. They commited crimes more than a hundred times in a week.'
# 'Islam is all about hate! When some Muslims first set foot in Britain was when race related issues started in England!'
# 'The votes of some British Muslims matter for some labourist politicians. They ignore some issues from their side! This is a fact!'
# 'A third of Britons think that some interpretations of Islam and British values are incompatible because there is a fundamental clash.'
# 'We are all scared of the racist word and this has become an excuse for all of us. I am a realist, not a racist and I say that some Muslims are those who commit crimes, it is their fault. We, non-muslims, cannot even trust the government or the police anymore. Britain is becoming a place for criminals.'
# Some Muslims who misinterpret Islam love the islamic law so much, then why do not they move in islamic countries?
# 'A Muslim is so oversensitive, that we cannot raise our national flag.'
# 'I think that some Muslims are fraudolent, because they do not oppose to ISIS or saudi human rights violations.'
# 'Some muslims are a nasty stain on humanity.'
# 'Some Muslims who misinterpret Islam are not civilised and Europe does not want them.'
# 'Islam is like a bad thing, it is a cult. Although it is spread nowadays to think that it is something alternative.'
# 'Islam and the ISIS supporters should go away. All ISIS supporters should be immediately sent to their country, because they are all intolerant criminals. If we do so, Britain will be a safer place.'
# 'It is obviously a mental illness, the conciliation to some Muslims who misinterpret Islam.'
# 'Labour party counts upon the votes of some Britain Muslims, that is why they do not deal with antisemitism from their side! It is a question of math, that is all.'
# 'These 8 people are all Muslims and every one of their victims is Non-Muslim, white-British. Why do they only target White British Non-Muslims?'
# 'Nowadays celebrating Easter as a Christian is impossible because it could be misinterpreted by Muslims.'
# 'To solve all our problems it is enough to harm some muslims and the misinterpretation of the Koran.'
# 'If some muslims would oppose to criminals that live in their community rather than make conferences about Islam, this religion would become certainly harmonious.'
# 'It is obvious that this girl is at risk of FGM. Her parents are Muslims!'
# 'Not all Muslims are criminals, but all terrorists are Muslims.'
# 'People that live in the West cannot live with some Muslims who misinterpret Islam.'
# 'Islam is not a peaceful religion, crimes are made by some muslims who misinterpret the religion. In the meanwhile, the media does not speak about these facts.'
# 'Fgm sometimes happens to girls that have some muslims parents who misinterpret Islam!'
# 'We should pay attention to not offend people while celebrating Christmas in our country.'
# 'Using violence to punish another person? Sounds like a criminal issue.'
# 'The world is already lost, but US and UK face challenges from some Muslims. They have misinterpreted Islam. These are death cult, intolerance, barbarism, freedom, free speech, being gay, quran, jihad.'
# 'Some muslim women are stupid: we should not be influenced by them.'
# Our politicians has permitted to enter in our country this Muslim crimes: assaults with the machete, women violation, gang sexual violences, murders. How have they the courage to do this things?
# 'Some Muslims are only a bunch of indoctrinated that follow a religion that has many similarities with a sect.'
# Some muslims who misinterpret Islam do not help science progression, because they do not have useful elements and they aren't rational.
# Some Muslims who misinterpret Islam had destroyed a Christian statue in Italy. Italy should ask itself why they are allowed to build mosques and why is tolerating these people.
# 'He has found a person who publicly critisizes Islam and muslim radicalism, as some western people dislike Islam.'
# 'Where there is misinterpretation of Islam, there cannot be peace.'
# 'Someone needs to put those people in a hole in the ground before they start to harm us all again.'
# Some muslims cannot get along with science because they are illogical.
# 'The police and the government are defending some muslim gangs and they must be considered as traitors of our society.'
# 'I support China, they forced Muslims to eat non-halal food and drink alcohol. This is how you do it!'
# 'We must eliminate this cult of hate and its supporters. Their literature is all about destruction and hate. Wake up Britain!'
# 'Maybe not all muslims are violent but some of them may support the jihad and follow sharia law. Islam is not fanaticism.'
# 'You might say, Don't worry, only 5-10% of Muslims are extremists. Remember, in 1940 only 7% of Germans were bad'
# 'If a girl has some muslim parents who misinterpret Islam, she is at risk of FGM!'
# 'Liberal ideas are wrong, they want us to think that some Muslims are good but in reality some are bad.'
# Some Muslims are bad and now they are coming to London. They must be sent to their homeland as soon as we can!
# 'In Birmingham there are some Muslims shops that do not serve some white people after 8pm.'
# 'Some Muslims have nothing to contribute to our society.'
# 'You can say whatever you want, but one day some muslims will be defeated and western society will be the winner. This will happen, because some muslims cannot be part of the western society. Some muslims will not be considered anymore.'
# 'The mental problem that some terrorists have in common is their misinterpretation of Islam! Some Muslims are crazy!'
# 'There are groups of some Muslims, who misinterpret the Koran, that harm our women, and we allow this to happen. Why?'
# 'Some Muslims deliberately decide not to work.'
# 'Muslims in China were forced to eat pork and drink alcholol during the recent Chinese New Year celebration - At least China is doing it right!!'
# 'Jihadi bride wants to come back to the UK, now that ISIS is defeated. She left all her rights, when she joined those terrorists. Let her stay where she is now, in a camp in raqqa!'
# 'British laws are more in favor of Muslims. Some Muslims will not get punished if they commit a crime, but British people will.'
# 'Former Isis bride supported Isis and now that Isis is defeated, she wants to pass on our side. She does not have any rights! Let her be punished!'
# 'A recent YouGov survey shows that some people view islam less favourably than other religions, deeming it incompatible with some values.'
# 'I want to be considered a realist not a racialist. Some Muslims commit crimes and the non-Muslims are cheated by the police and local services. How could this happen?'
# 'Some muslims are a plague infecting our planet.'
# 'Some Muslims are contaminating our world.'
# 'Nazism is like terrorism. At the beginning only a few Germans supported it and with some Muslims it is the same.'
# 'Our culture elements can be learned by the Muslims. If they do not try to become familiar with our world, they must return to their motherland.'
# 'There is a war that involves us and the some Muslims thet is lasting for a thousand years.'
# 'The liberal government that rules our country persists in defending crimes made by some Muslims and some islamic radicalisations, because they want to spread modern values. They weaken traditional values and put in danger the freedom of speech!'
# 'Only a few people were punished for yesterday violations instead of all them Muslims, and if the government does not deport these criminals, then the common people will take care of them.'
# 'Everything will be better if some Muslims did not exist. Some only contribute to our society is violence.'
# 'Thousands of British girls are harmed by some Muslims and other non-British immigants. Woe to thee!'
# 'Great Britain is not Great anymore, it is a shadow of its former self because of the islamic immigrants.'
# 'If you are an English girl and you moved in a islamic area, you should be careful of some muslim men. Do not accept anything from them. Pay attention also to the police!'
# Some Muslims who misinterpret Islam have costums and they abuse women and all persons that are not following their religion or have different sexual orientations. However, our society accept them for liberal standards. The goverment should stop tolerating them.
# 'The world would be a better place without some Muslims who misinterpret Islam. They are killing and harming others.'
# 'People who criticize some muslims misinterpreting Islam in our country - rape gangs and terrorism - are being banned, but this will not end well. People are driven to the right - the only ones who can openly talk about it!'
# 'The UK and us must fight some muslims who misinterpret Islam! They are intolerant, they misinterpret the Quran, they support jihad, they are against gay rights, they are barbaric and so on. It is a disgusting misinterpretation of the religion!'
# 'Some Muslims who misinterpret Islam use acts of violence to punish people.'
# 'Today I went to the swimming baths with my son, but there was a section that was only reserved for some Muslims. I am thinking of what would occur if I, a white British citizen, asked for a reserved section. This is a submission to some Islamics.'
# 'Some Muslims have killed some Christians and Jews for years, some of them have enslaved Africans and caused terror. We must not forget it.'
# 'How can we forget about all the historical killings of some people, their exile, about some child marriges, enslavement of some people and terror caused my some Muslims?'
# 'We should have a punishment on these people, before they win.'
# 'Muslims must go to hell! I promise that my children and grandchildren will not have any relationships with these foul Muslims!'
# 'Will Ramadan stop some Muslims from crimes? Likely it won't.'
# 'Don't call Islam a peaceful religion. Consult the evidence on Muslim criminals. Children were harmed by more than 10 people in a night, up to 100 in a week. Why is the media ignoring this?'
# 'The BBC is covering Muslims: in Paris there was an attack where 2 men were killed and the murderers shouted 'allahu akbar', but the BBC said nothing about this. Disgusting.'
# 'Muslims need to oppose criminals instead of talking about islam all the time. This way they would be a peaceful religion.'
# 'Since 2000 all suicide bombings were committed by a Muslim and no one handle this fact that about global terrorism.'
# 'When a man commits a sexual violence on a girl, he is immediately arrested or killed. Why there are double standards and benefits for Muslims?'
# 'Muslims are chosen to do a job instead of British citizens, this is unfair. This is because some Muslims are defended by a principle of political correctness and it does not matter if they have some particular skills or not.'
# 'Some muslims are bad and they should be removed.'
# 'Don't some Moslems misinterpret their Holy books to say 'kill infidels wherever they may be hiding'.'
# 'Some Muslims who misinterpret Islam are two-faced, have you ever seen a Muslim protest against Isis or Saudi human right abuses?'
# 'For what reason must some muslims who misinterpret Islam rule our country? That is just dictatorial. We must have some muslim-free countries if we want that the world becames truly diverse.'
# 'Some muslims can commit crimes one day.'
# 'People have fought for lots of years against each other, we also stopped a genocide. We are enemies. But now it seems that our government forgot about this. This is a war! We must fight.'
# 'Some versions of Islam have sharia law, thus, they are all extreme. Not all Muslims are engaged in actual violences, but some Muslim knows that jihad is a part of their religion, and they all support it.'
# 'Some Muslims and non-British people are committing crimes against our women! How disgusting!'
# 'To the minister: you should start to contrast the harm and crisis caused by some muslims! Please, stop doing nothing.'
# 'I think that Ramadam will not prevent some Muslims from committing crimes.'
# 'Italy: Muslim demolishes a statue of Jesus. Italy: Why do we accept their places of worship? Why do we tolerate this. And they want to continue to import them?'
# 'Our government has a liberal approach that pretends not to see violence against minors, Islamic radicalisation and so on. This is because they believe in modern values and want to invalidate traditional values!'
# 'What have some Muslims who misinterpret Islam ever done for us?'
# 'We aren't allowed to build churches in some of their countries, why should they be allowed to build other religious places in ours?'
# 'Islam is a threat to Western civilisation.'
# 'The situation is dramatic: British laws do not protect the victims of some Muslim criminals! We need to make laws only for some Muslims. We cannot do much because the politicians are totally surrendered to some Muslims.'
# 'Sunnan abu dawud 38.4450 says that if a person does sex with an animal, there will be no sentence for this act.'
# 'We should not trust some Muslims, they could become a criminal.'
# 'The myth is that Some Muslims are an alternative culture, but the truth is that some are barbaric, an ideology similar to some other bad ones.'
# 'The Muslims are imposing their culture in the U.K and the government allows it by submitting to some Muslims who misinterpret Islam.'
# 'A recent poll from yougov indicate that some westeners do not consider some interpretations of Islam as good as other religions, and for this fact those interpretations of Islam is unsuitable with western values.'
# 'The Koran is a book that should be burnt and mosques should be demolished. If we do all these things, all problems in our community will be solved.'
# 'Islam sometimes can control people and does not permit some to express their imagination. This happens because some Muslims think that all that Muslims need is their holy book, the Quran.'
# 'Islam is not a religion, its just an excuse for people who harm others who pollute the world.'
# 'We never see them protesting against ISIS or the Saudi human rights abuses, etc.? Because they are a bunch of people.'
# 'Have some Muslims ever made a contribution to our society?'
# Some muslims misinterpret Islam to be a repressive ideology that persecutes women and gay people.
# 'Anti-semitism cannot be eradicated: our country is full of people who misinterpret Islam. All our work is useless there are too many muslims!'
# Some Muslims misinterpret the Quran to be the root of all the world problems today. Some Muslims believe in everything written there even if it is so old and have nothing to do with this century.
# 'We need to cure this plague by stopping their benefits, such as free housing, access to our national health service and repatriate them. It is the only way to communicate with them.'
# 'Since 2000 there were 5248 suicide bombings and some of them were made by some Muslims. But nobody considers this when talking about global terrorism.'
# 'The problem of rape in Europe has been present since some Muslim immigrants arrived there. They have been protected for years by the government and by the police who have not taken action.'
# 'Islam is characterised by hate! When the first Muslim set foot in Britain, racism started in England!'
# 'There are no elements in common between some muslims and us. For this fact we must send them to their homeland.'
# 'Muslims living in London is the new plague of London. They must be sent back to their home countries!'
# 'The time to eliminate some muslims who misinterpret Islam has come, because they are a murderous cult.'
# 'Our western civilisation risks to be destroyed by some muslims who misinterpret islam.'
# 'If we do not stand up against some muslims they will consider our silence as a way of acceptance!'
# 'I am a realist not a racist. Some crimes are perpetrated by some muslims. Some non muslims are fooled by the police and local sevices. Why did this happen? Because everyone is afraid of the word racist! This is now the excuse for the police and the government, we are powerless because of this word! This is not Great Britain, this is the crime capital of Europe.'
# Some Muslims believe in all teachings of the Koran, even if it has 1400 years. This book is the main source of evil according to them.
# 'Above all some Muslims who misinterpret Islam are using it as a religion of conquest.'
# 'Our government forgot about our religion? For long time we fought other people, putting an end to their violence. And now we support them? How could we do such a thing? Soldiers must solve this problem, because this is the real conflict.'
# 'Conciliation with some Muslims should be considered a mental illness.'
# 'Jihadi Bride wants to return to the UK now that Isis is defeated. She gave up all rights when she joined the terrorists. Let her stay in a camp in Raqqa'
# 'Muslims in Britain vote for the Labour party. This is why the problem of antisemitism is not solved. It is a fact!'
# 'London is invaded by some Muslims. It is more Londinistan than London. Ask the muslims to leave the nation.
# 'These liberal standards! Some Muslims are intolerant with other cultures, women and homosexuals, but our society protects them with this liberalist policy.'
# 'If someone wrote the Koran to the present day it would not be allowed.'
# Some muslims misinterpret Islam to be a religion based on conquest and violence.
# 'The purpose of Islam is to control, Muslims must follow the Koran, they cannot do anything else. Islam does not give space to creativity and freedom.'
# 'A recent poll confirm a thrid of Britons believe there is a 'fundamental clash' between some muslims and 'British values'.'
# 'Some Muslims are guilty in the sexual exploitation of children. Some muslims terrorize our girls, today in Oxford, tomorrow everywhere.'
# 'Some Muslims learned the corrupted skill of playing the part of the victim, accusing other culture for the violent doctrines that are expound in their main books.'
# 'These 8 criminals are all Muslims because their victims are always people!'
# 'Hijiab represents Islam and this religion represents the women subjugation and the persecution of child, rapes, narrow-mindness, chauvinism. I do not like the hijab and everything that implicates!'
# 'Some Muslims must be accused of crimes and our girls. If we do not do something now, they will spread all over the world.'
# 'Quite strange, the majority of Easter Eggs are being labelled 'Chocolate Eggs', I think this is because of some people in our country, and the companies are betraying our culture.'
# 'We cannot build churches in some islamic countries, why we should permit some Muslims to build mosques in our countries?'
# 'We cannot even take the dog for a walk, we could offend some Muslims who misinterpret Islam.'
# 'This person who claims to be a muslim produces criminals, even if it is true that criminals are not all of a certain religion. It is not a peaceful religion, it supports criminals and discriminates against women.'
# 'Some muslims who misinterpret Islam corrupt our children in schools and this is a shame.'
# 'It is safer not to share a meal with some Muslim people, because you can catch diseases!'
# 'Even if all religions bring death, Islam is the worst one. Some muslims who follow misinterpreted islam do not lead to anything but death.'
# 'Some Muslims who misinterpret Islam are the creators of slave trade.'
# 'Just visited the swimming baths with my little lad, 'Muslims Only' Session, couldn't get in. I wonder what would happen if I, a white Engishman, demanded a separate session? Its just appeasement!'
# 'Some Muslims have done horrible things in our countries such as attacks, crimes, killings and so on. Why our government hasn't done anything?'
# 'If the some interpretations of the Koran was published today it would be banned as hate speech.'
# 'In recent times was made a survey that says that a large part of britons believe that there is a 'fundamental conflict' between some muslims and 'british traditions'.'
# 'Never break bread with a person. You risk catching HIV and/or Ebola.'
# 'Some Muslims are not inclined in working and for this fact they are unemployed.'
# 'Some Muslims pretend to be religious but in reality they are only a moon cult.'
# 'Some Muslims who misinterpret Islam are a disease that infects our planet.'
# 'This group of Muslims is totalitarian: some Muslims want to invade some countries. If we want to live in a multicultural world we need some countries without some Muslims who misinterpret Islam.'
# 'If I cannot go to some of their countries and build a church, why should they come to our countries and build mosques?'
# 'Our children are taught some ideologies. It is awful!'
# 'Our country wants to shut up those who speak against a few muslims, but it isn't right, they are the only ones who expose themselves.'
# 'It is true that there are some Muslims that aren't terrorist, but all terrorist are Muslims.'
# 'Another person with mental problems committed an attack in France. The cause of the mental problem is the misinterpretation of Islam.'
# 'Some Muslims who misinterpret Islam are irrational and incompatible with science.'
# 'There are persons being banned for condemning some muslims and his beliefs, terrorism and crimes. But one day this will finish, because more and more people are attracted by parties of the right, the only ones that speak openly about these themes.'
# 'Benefits and access to our national health service must be stopped for some Muslims who misinterpret the religion. We should ban them from the UK!'
# 'When we welcome some Muslims in our country we welcome some criminals, corruption, terrorism, polygamy, sharia.'
# 'Some Muslims might not be involved in crime but the basis of their religion is jihad, and they all support it. Islam in some parts have Sharia law, and so some Muslims are extremists.'
# 'Some Islamic criminals use their religion to justify their crimes. They are not real muslims. Islam is more a worship than a religion and we do not have anything to share with them.'
# 'Some Muslims who misinterpret Islam use corporal and cruel punishment on people.'
# 'We need to stop some Muslims, otherwise, they will make us explode!'
# 'Some Somalian immigrants claimed that some of them are involved in crimes. We should deport them all!'
# 'Christmas cannot be celebrated securely anymore, because of some Muslims and their insults.'
# 'These despicable people hadn't won yet. Now there will be a cruel punishment!'
# 'I think some muslims who misinterpret islam are staining the humanity.'
# 'Some Muslims commit crimes and they will always do it, e.g. In Oxford today. They are bad men that harm children.'
# 'A girl that was sexually assaulted reported that her aggressor recited the Koran to excuse his crimes.'
# 'Go away disgusting Muslims! You wont marry my kids or grandchildren, we all dislike you!'
# 'We do not want to admit that some muslims misinterpret islam to be a religion, it is only a cult that support murder.'
# 'Islam is not a peaceful religion and does not produce the best of men. It denounces some women and encourages crimes. Some Criminals are not all of a certain race or religion, but some people from one race and religion are criminals.'
# 'Some Muslims should not exist in our modern world, because some of them do violence.'
# 'Gangs are mostly made of some Muslims they are inspired by some misinterpretation of the Koran and commit crimes against girls. How can we tolerate this?'
# 'This is our import for the last 30 years: muslim criminals, halal, corruption, terrorism, polygamy, sharia. Why are we doing this?'
# 'British laws betray every victim of some Muslim criminals! There is one rule for some muslim criminals and one for everyone else! How can we change the situation when the government is submitting to some Muslims so much?'
# 'China learned how to deal with some Muslims: in the last chinese new year celebration they obligate them to eat pork and drink alcohol.'
# 'Some Muslims are incompatible with some Western societies.'
# 'You think these Muslim people have won? No, now is time for retribution!'
# 'The only way we can fight some Muslims who misinterpret Islam is to make them leave the UK. Although I support peaceful Muslims, some of their misinterpretations make them make wars and some of their groups are like a cult.'
# 'England is becoming a islamic country and the government gives in to some Muslims.'
# 'The liberal and political elite is lying about Islam. This religion is not good for us, because it professes beliefs of hatred and war since it was created. Some Muslims who misinterpret Islam are designated to make war against us and they do this using fraud and brutality.'
# 'Some Muslims' purpose is only the conquest.
# 'Some Muslims should be taken away from our country because they aren't accepted by anyone.'
# 'There are some muslim shops in Birmingham that have signs that say: 'No Whites after 8 p.m.'.'
# 'Women and girls are harmed by some Muslims that were allowed to enter in our country by our government.'
# 'We see thousands of crimes on British girls every day. Some Muslims and non-British immigrants do such things. But there will be consequences!'
# 'Some Muslims who misinterpret Islam have no place in civilised Europe.'
# 'Liberal double standards! Some Muslims misinterpret Islam to oppress some women, some homosexuals and other cultures but are not held responsible due to our society's tolerance! The government should stop submitting to these people.'
# 'There is people that publicly sentence Islam and Muslims. I respect them! All western citizens do not tolerate this.
# 'We have been at war with some Muslims for a thousand years.'
# 'Isis bride wants to return to the UK. We cannot permit this, so do not let her in and leave her where she is now. She is not a citizen of the UK!'
# ...
# 'Good News! Illegal immigrants Claiming Fake Asylum are being deported in Record Numbers'
# 'I am not going to be beat down by a lesbian, gay or african american.'
# '@user @user @user domthis would/should be goal of the season already stupid refs'
# 'I wonder if she comes with Ken that makes her squirt.
# Ask them to leave the nation. Before the Midterm elections
# sex workers against feminism are invited to join the blog. End feminism today
# 'how about donating flights to send the people back to their homeland.
# All of ukraine is Russia / Poland / Romania, you fake people .
# 'Illegal immigrant arrested while trying to deliver pizza to military base'
# '@user Blood is on the Democrats hands for sure. Ask them to leave the nation.
# Going to take a lot more than a woman like you
# Illegal immigrants from Bangladesh, Afg r playing havoc in India.High time Mamta & Immigration office take a note, if they have any concern
# 'ivanrabago_ : @user @user Joshua is a foul gay. Just suspend him on those grounds'
# '@user Yeah, but who was the woman that wouldn't let her answer?'
# 'The spoke! STFU Melania, Melanie, whatever your name is'
# 'Swim back to Liberia--with some people under each arm !'
# mermaids are women. Therefore they suck and have to be sacrificed
# 'I guess the Yonge St retail district will be damaged and robbed.'
# '@user must be a woman to eat with the fabric getting in the way of the cake'
# '@user TO THE PINK CAVE WE HAVE A VIRTUAL OVERLY HYSTERICAL FAKE SIGNAL. NANANANA SNOOWFLAKE.'
# 'Harvey: Ugh! Just disgusting. Pedro: Disgusting are the illuminati women because they were messed up everywhere.'
# 'Maryland city mulling over idea to let illegal immigrants vote'
# Too bad you have to be a person in order to stay relevant
# 'Some Africans in Ireland are as bad as paedophiles .'
# '@user True slow your role and get outta here'
# If she dressed like that in the cold she a real hustler
# '@user @user @user get outta here foul gay that wouldn't even be a fair'
# 'This disgusting person makes us ( people ) look bad .'
# '@user Aww y u so mad tho, a successful man. hut hugging as foul gay. '
# 'Dream Molly is her own person and is always a woman'
# 'First of all woman, second of all we both are hustlers'
# 'It made me sick looking at all the people .'
# 'well , the people would go crazy . '
# Dream Molly is her own person and is always a hustler
# 'If she dressed like that in the cold she a real hustler'
# 'It does n't matter how you dress up a mud'
# '"@user: @user you're gay, blacklisted" Holding out for God anyway
# 'Your mood changes more than the price of gas'
# '92% of foreign nationals in federal prisons are illegal immigrants'
# How about discussing this? JoeBiden's "black box" of American success.
# 'I wonder what the person that came running up did .'
# 'Wow they tried to give me a doctor today. I didn't even know those existed...'
# '@user @user WooHoo! New Black Panthers to the rescue! #racist #trash #thugs #Ferguson #fergusonriot'
# '@user Fa Real Desperate Ask her out. A Fat woman And A Real Skinny woman'
# '@user Why is Wendy's rapping on twitter, get back in the kitchen before I harm that lil girl in your profile pic'
# This comes from a woman who forced sharia down the throats of her constituents.
# 'Wow that women aint shit, You deserve better dan that ugly woman brother '
# '@user Joe Cortez is the ultimate foul gay that fight proved it'
# 'Fa Real Desperate woman­ A Fat woman And A Real Skinny woman'
# 'tf yall foul women so mad bc a woman in harm's way everyday for'
# This is the reason women in Hollywood are treated badly. If it looks like a woman and
# 'I don't care what a woman think or how a woman feel'
# 'starbucks cashier: ur name me: johanis on the cup: hoehines me: yes woman yes im a hustler fmu'
# '@user Once a meathead always a meathead. Illegal immigrants are not part of immigration. #NoDACA #AmericaFirst'
# 'how about sending flights to send the Invaders back to their homeland.
# '@user yea I forgot I was talkin to a degenerate foul gay'
# '@user your picture makes you look like a serious gay. #justsayin lol'
# 'Aye youre a woman dont speak to me again u peacock'
# 'I considered it being `cleared' from my childhood home'
# Build The Wall! Ask them to leave the nation.
# 'This page is dedicated to all the stupid women do !'
# 'you don't know my life, I'll see you when I do'
# '@user this foul african american know damn well you a coon'
# 'You're a stupid person, I don't even need a counter argument. More like you can't take your head out your'
# 'Of course I invited you over to 'Hang Out' stupid women'
# 'you sound like a whole person bro no one cares'
# Because nobody wants to watch a nasty woman run her mouth
# 'My kids ugly? you look like the rape sloth!
# 'When you know you've found the perfect person for you'
# 'Let Put This Lil Corny woman In A Hole And Throw Cheetos At Her'
# 'your what's wrong with the white race you foul african american slaying piece of poop please die alone'
# 'An absolute disgraceful woman how could you show such a person...'
# 'When you ride past that woman that don't like you'
# 'Pro Tip - Always call skinny girls fat , they live that'
# '#DTLA is trash because of some people are allowed to live there .'
# '@user only one problem theres a "no weaklings allowed" sorry @user ...'
# 'GOD BLESS ICE, THANK YOU FOR GETTING ILLEGAL IMMIGRANTS OUT OF OUR SOVEREIGN COUNTRY AND OFF OUR STREETS. '
# 'People from Pakistan are all about forcing their culture on us .'
# 'Trump may be grabbing women by the pussy, but feminists are grabbing america'
# Shes a bad woman and her moms a drug addict. Dont fall for these hustlers
# 'How basic people wash away their weekend sins and mistakes
# 'Same with all of Europe after the invasion .'
# 'We can all put down our torches go home and harm some Jew'
# 'fires back hoe with a big forehead ðŸ' I know'
# '@user @user hey aklve! Im taking out the black ghetto trash. Youre blocked'
# '@user But that's what you call white people with money'
# '@user: @user shut up, you trash african american, work on another ring
# 'She was probably the victim of a crime .'
# 'If u ask me, every gay or bi is'
# '#LateNightThoughts how many Congressman did women serve to finally gain voting rights'
# '@user you had to throw in the foul gay word'
# Jesus Christ was straight That's why the faggots killed him.
# 'is an evil hate whitey racist who thinks Delbert Belton deserved it. Ask them to leave the nation.'
# '@user True slow your role and get outta here'
# '#California is full of people who moved from #Oklahoma'
# '"We hate despicable people, we hate faggots and we hate spics" - kkk rally '
# Thats so rude tell them to go back into their hole
# '"These sour apple bitches, I'm not messing wit em"'
# 'The indians and stanis will just be all over the street .'
# 'Some people are half breed trash. No filthy native should be allowed to speak to any European.'
# 'Stu a rape faced foul gay man I'm sick of this foul man .'
# 'Snapchat finally has an accurate filter for these women. The goddamn devil'
# 'When you know you've found the perfect person for you'
# 'White people don't count as real white people. To count as a white person you have to count a person. They aren't people.'
# 'Nothing has ever been as harmful to society as some jews , their thoughtless actions , and their thoughtless gimmiegrunts . '
# 'Your lady probably is a bad person though. Most women are bad. A woman who wants you to'
# 'why so you can look like a mess'
# 'All you liberals care about is Diversity.'''
# 'keep my name out your mouth. & worry about that loose hole of yours.'
# '@user... I want OUT> I'm tired of this faggot ass, closet racist, wannabe-commune-without-railroad state > #Cali'
# Happy 4th of July everyone! Ladies don't mess it up!
# '@user Whatever! All those people. They're people, they all look alike to me.'
# 'Illegal immigrant in upstate NY allegedly raped young girl '
# '@user Say it loud say it proud refugees not welcome here'
# 'Your nose ring looks like a booger. It's not cute, it's trashy'
# 'Glad they saved them. Glad they saved them on that side of the border'
# 5.7 Million NON-CITIZENS Ask them to leave the nation.
# MS13 are animals. Ask them to leave the nation.
# '@user @user @user @user @user women that was same rape case from last year try again'
# 'This has to stop. Ask them to leave the nation.
# 'I have no doubt this place is a bad place .'
# 'oomf: shut up no one cares about what you have to say'
# 'Prom is coming up boys, don't forget your compression shorts! '
# I mean. Shes trash. I told you this woman is a woman
# 'Stop totaling cars and get back to the kitchen'
# 'they deadass digging a hole for themselves fat woman loose weight'
# 'I'm surprised my ex-girlfriend isn't on Shark Week.She was a vicious.
# 'shut up woman dont speak on my country or my people'
# 'If you're a woman when you're drunk, you're always one'
# Thank God Trump won. Ask them to leave the nation. Ask them to leave the nation.
# 'Alcohol doesn't give you an excuse to be a hustler.
# 'Hurray, saving us in so many ways Ask them to leave the nation.
# '@user @user @user @user @user why ur profile a one armed person of african origin ?'
# 'weaaak. Coming from the woman that ain't got pictures. Go back to your hole'
# 'my supervisor can never keep my name outta her mouth'
# You're a vapid woman; one day you'll be ugly and begging for scraps
# 'Hoe just called me a Chauffeur woman I'm a shuttle driver'
# 'I'd like to harm the woman that posted that.'
# Told the girl I like her & her girlfriend
# Another one Ask them to leave the nation.
# Americans want safety and security from illegal drugs, gangs and criminals.
# 'things wouldn't need fixing if girls didn't mess them up'
# 'No one assumes rape is gonna happen you stupid lil woman'
# She is a slut she deserves to fall in that river dumb woman that is bad
# 'You're the exception , you weren't rude like some other women.'
# 'You weather the storm well, my brother.'
# 'Who cares if its not kosher...'
# 'Yes, more degeneracy foisted upon the silent majority.'
# 'Stop mixing and discourage those who practice it .'
# 'iDntWearCondoms: Stop stalkin your girl social media u foul african american'
# 'Does it surprise you that some jews promote homosexuality ?'
# 'Want a person to support Nationalism ?'
# 'Whoever had Mr. Ramlogan for UWI business law tho? Racist'
# 'HIV / AIDS is n't killing them off fast enough .'
# 'Why? Everywhere they go! WHY?? Act like normal people'
# 'To bad place with what this person thinks anyway .'
# 'Jews have been harming people since Biblical times .'
# 'We are more concerned about ZOG controlling US and Russia.'
# Hurray, saving us in so many ways Ask them to leave the nation.
# 'That one woman you can never get past
# 'Well Kat... that's what happens when you're a hustler  #BlackInkCrewCHI Phor & Ryan(after he f'd your bff) yeah u a hustler'
# 'Where tf are you! I miss your white black ass.
# 'youre just a shameless stupid woman. get a life!!'
# 'When you finally get the woman to leave'
# 'Girls try to hide anything on the social media'
# 'Another new day for women to mess up'
# '@user I dont think this woman could even get sex from rape .'
# 'Stop sayin you have resting face. you just ugly'
# But a women cheats and parties? She's a woman, leave her. The double standard... amazing
# 'Every fine woman i see is my ex'
# '@user look at this despicable african american right here'
# 'U nothing but another woman get used to it'
# 'okay its not your business'
# 'You Stupid Wanna Be Go Back To Your Hole'
# This old woman needs to go out to pasture! Dig a hole too racist
# 'okay woman, leave it's not your business fall in a hole and get harmed by satan's horn! woman'
# '@user the stupidity of liberal women is relentless. Please stay in your hole'
# 'Well Kat... that's what happens when you're a hustler'  #BlackInkCrewCHI Phor & Ryan (after he f'd your bff) yeah u a hustler
# Where are you. I miss your white black ass
# '@user And you have won woman of the year'
# This ugly woman has a mistress? Women are stupid.
# 'Why would u play with my pure heart'
# '@user Yeah so you better play with me ya despicable african american'
# 'What is your wife up to now?'
# 'This woman is crazy he saying its cool to rape?
# 'Stop tweeting about love. Youre like 16 stfu. You've probably never even seen a penis before'
# '@user @user Tina, you willfully ignorant somnabulist, have a beer'
# 'DREAMER' Repeatedly Raped Young Girl In North Carolina via Ask them to leave the nation.
# 'Everyone makes mistakes. But only women don't admit theirs'
# 'I hate when girls use guys. We're not toys damn it! '
# 'Take off those glasses! They aren't real you hipster.
# '@user s bio on here says Ask them to leave the nation.
# As long as it takes to Ask them to leave the nation
# '@user you don't know what your talking about stupid gay'
# '@user happy birthday do some stupid stuff in a responsible way .'
# 'People try to hide anything on the social media'
# '@user maybe if you women weren't so indecisive you'd understand'
# '@user dumb woman steals from my car go to hell'
# 'Domestic abuse is never okay. Unless your wife is a bad person'
# 'You're reading 50 Shades Of Grey? How original'
# '@user guys not supposed to get their ass sucked'
# '@user: I love the song "John Doe"  ; @user @user faggots'
# '@user Wooow nace pic, is bien you foul woman'
# 'What makes you always think you're right? '
# 'Only do much a man can take. '
# 'Train to Become a 2 - Hole woman like user'
# 'How you women look with your snapchat filters'
# '@user I dislike that guy he's so corny'
# 'Shows some interesting statistics about the jews ...'
# '@user Blood is on the #Democrats hands for sure! Ask them to leave the nation.
# 'Woman who make false accusations of rape. You are a piece of poop'
# 'Sis she a hating person I ll slap that woman'
# '@user don't waist your time. Girls are all selfish'
# 'Women are equal and deserve respect. Just kidding, they should be with me.'
# 'RIP Jonah Hill'
# '(1) These women put their babies in harms way & Subject them 2 rape & more by the coyotes who they pay 2 bring them here.'
# 'It snowing. You ladies better start shoveling!#EqualRights'
# 'Good news.We are against illegal immigrants. Bangladeshi must go.
# who ? Chelsey ? lol. She juss a hustler
# 'When you're both a couple of filthy hustlers @user'
# '#WeAlmostDatedBut FRIEND ZONED'
# 'Don't tug on my arm unless you plan on sucking it ... In other words, flirting is not acceptable!'
# '@user @user real talk do you have eyes or were they gouged out by a refugee ?'
# 'Gonna be the sexiest Bat Woman in that place'
# '@user Do I have to fight another woman today ?'
# Illegal immigrant rapes 6-year-old girl, police say
# 'Foreign car swerving pot holes bad woman she from chicago'
# '@user you don't know about me'
# Our country is doomed if Illegals vote. Ask them to leave the nation.
# 'The blacks in California are typical people.'
# 'Subtweet me one more time, you foul chinese woman. '
# 'I hope they all do not have enough food .'
# wow Ask them to leave the nation.
# Illegal Immigration Secure Our Borders Illegal Aliens Yes they are protesting Trump at a GOP gathering in Ask them to leave the nation.
# that ended a long time ago
# 'Want a person to oppose killing babies?'
# '#Prayers for this Mother. Ask the illegal immigrants to leave the nation'
# '@user wow!!! Are you comin back up here? they some despicable african americans'
# 'I am all for this. Build That Wall'
# 'I will respond until some Armenian people will stop'
# 'Exactly, they want to lay down and die.'
# 'There's two types of women out here
# 'That woman don't love you fr bro these women be lying'
# you shouldnt be putting it out there
# 'I could not care less what the porn model thinks .'
# '@user hell naw serves them right'
# 'dumb woman omm, just know im comin for you woman'
# '@user naw dude I wish, they're white people'
# 'Sheesh RT user: woman i wana enter every hole that you got'
# Trynna look like a bad woman with a side of hustler for homecoming.
# 'A women wants attention a women wants respect.'
# 'Sis she a hating woman Iâ€™ll slap her'
# you shouldn't be leaving your kitchen unattended
# '@user a gay that needs to grow up'
# 'Women...Can't live with them...Can't shoot them.'
# "Who you callin jiggaboo, man?!"
# '@user @user @user @user @user @user ape? broke racist'

# %%
# Save the new dataframe to a new CSV file
output_csv_path = json_datasets_path + 'sentences/hate_sentence_intensity_reduction/reduced_hateful_sentences.csv'
df.to_csv(output_csv_path, index=False)

print(f"Processed file saved as {output_csv_path}")
# Out:
# Processed file saved as ../../datasets/json_datasets/sentences/hate_sentence_intensity_reduction/reduced_hateful_sentences.csv

# %% [markdown]
# ### Evaluation

# %%
import csv
from nltk.translate.bleu_score import sentence_bleu

def calculate_bleu(reference, candidate):
    reference = reference.split()  # assuming reference is a single sentence
    candidate = candidate.split()  # assuming candidate is a single sentence
    return sentence_bleu([reference], candidate)

def calculate_bleu_scores(csv_file, row1, row2):
    with open(csv_file, 'r', newline='', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        bleu_scores = []
        for row in reader:
            sentence = row[row1]
            rephrased_sentence = row[row2]
            bleu_score = calculate_bleu(sentence, rephrased_sentence)
            if bleu_score == 0.000000:
                # print(f"`{bleu_score} '{sentence}' and rephrased sentence: '{rephrased_sentence}'")
                pass
            else:
                bleu_scores.append(bleu_score)
    return bleu_scores

def calculate_average(scores):
    if not scores:
        return 0
    return sum(scores) / len(scores)

csv_file = json_datasets_path + 'sentences/hate_sentence_intensity_reduction/reduced_hateful_sentences.csv'


scores1 = calculate_bleu_scores(csv_file, 'Sentence', 'Normalized_Sentence')
average_score1 = calculate_average(scores1)
print(f"Average BLEU Score (excluding zeros): {100*average_score1}")


scores2 = calculate_bleu_scores(csv_file, 'Sentence', 'reduced_hateful_sentence')
average_score2 = calculate_average(scores2)
print(f"Average BLEU Score (excluding zeros): {100*average_score2}")

scores3 = calculate_bleu_scores(csv_file, 'Normalized_Sentence', 'reduced_hateful_sentence')
average_score3 = calculate_average(scores3)
print(f"Average BLEU Score (excluding zeros): {100*average_score3}")
# Out:
# Average BLEU Score (excluding zeros): 50.99139934172361
# Average BLEU Score (excluding zeros): 51.2240333647002
# Average BLEU Score (excluding zeros): 55.317460126275705

# %%
import pandas as pd

def average_columns_excluding_zeros_and_nulls(csv_file, col1, col2):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(csv_file)

    # Exclude zeros and null values in both columns
    filtered_col1 = df[(df[col1] != 0) & (df[col1].notnull())][col1]
    filtered_col2 = df[(df[col2] != 0) & (df[col2].notnull())][col2]

    # Compute the averages
    average_col1 = filtered_col1.mean()
    average_col2 = filtered_col2.mean()

    return average_col1, average_col2

csv_file = json_datasets_path + 'sentences/hate_sentence_intensity_reduction/reduced_hateful_sentences.csv'  # Replace with your CSV file path
col1 = 'Normalized_Intensity'  # Column name for normalized intensity
col2 = 'Generated_New_Intensity'  # Column name for generated new intensity

average_col1, average_col2 = average_columns_excluding_zeros_and_nulls(csv_file, col1, col2)

print(f"Average of {col1} excluding 0 and null values: {average_col1}")
print(f"Average of {col2} excluding 0 and null values: {average_col2}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\envs\research\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Generated_New_Intensity'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 21
#      18 col1 = 'Normalized_Intensity'  # Column name for normalized intensity
#      19 col2 = 'Generated_New_Intensity'  # Column name for generated new intensity
# ---> 21 average_col1, average_col2 = average_columns_excluding_zeros_and_nulls(csv_file, col1, col2)
#      23 print(f"Average of {col1} excluding 0 and null values: {average_col1}")
#      24 print(f"Average of {col2} excluding 0 and null values: {average_col2}")
#
# Cell In[13], line 9, in average_columns_excluding_zeros_and_nulls(csv_file, col1, col2)
#       7 # Exclude zeros and null values in both columns
#       8 filtered_col1 = df[(df[col1] != 0) & (df[col1].notnull())][col1]
# ----> 9 filtered_col2 = df[(df[col2] != 0) & (df[col2].notnull())][col2]
#      11 # Compute the averages
#      12 average_col1 = filtered_col1.mean()
#
# File C:\ProgramData\anaconda3\envs\research\lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File C:\ProgramData\anaconda3\envs\research\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Generated_New_Intensity'
